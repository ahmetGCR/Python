# %%
# telefon rehberi uygulamasi
rehber = dict()
def tel_no_ekleme(x):
        while True:
            isim = input("isim giriniz: ")
            while True:
                try:
                    numara = int(input("numara giriniz :"))
                except ValueError:
                    print("sadece rakam giriniz.")
                else:
                    break
                
            x = rehber.setdefault(isim,numara)
            print(isim, "rehbere eklendi")

            while True:
                devam_mi = input("devam edilsin mi? (e/h) : ").lower()
                if devam_mi == "h" or devam_mi == "e":
                    break # bu break içteki döngüden çikmaya yarar.
                else:
                    print("Lütfen h veya e tuşuna basiniz!")
                devam_mi = input("İşlemlere devam etmek istiyor musunuz? (e/h)").lower()

            if devam_mi == "h":  # Bu blokla diştaki dögüden çikar.
                break

tel_no_ekleme(rehber)


def rehberi_göster():
    for anahtar,değer in rehber.items():
        print(anahtar, ":",değer)
print(f"rehberinizdeki kayitli kişiler : {rehber}")


def rehber_silme(x):
    while True:
        silinecek_kişi = input("rehberden silinecek kişinin adini giriniz : ").lower()
        if silinecek_kişi == "q":
            break
        if silinecek_kişi in rehber:
            x = rehber.pop(silinecek_kişi)
            print("kişi rehberden silindi.")
            break
        else:
            print("bu kişi rehberde kayitli değil, çikmak isterseniz q'ya basin :")
            continue




rehber_silme(rehber)
print("rehberiniz : ",rehber)
