# %%
# Python ile Pizza Siparişi
"""
Bu örnekte, Python dili ile bir pizza sipariş programi yazacağiz. Program, müşterinin seçtiği pizza boyutuna ve 
ekstra seçeneklere göre toplam sipariş ücretini hesaplayacak.

Müşterinin pizza siparişi için aşağidaki boyutlara göre ücretlendirilecektir:
Küçük boy (S) pizza: 25 TL
Orta boy (M) pizza: 30 TL
Büyük boy (L) pizza: 35 TL
Eğer müşteri pizzasinda extra peynir isterse pizza boyutlarina göre aşağidaki fiyatlar eklenecektir:
Küçük boy (S) pizzaya +2 TL
Büyük boy (L) ve orta boy (M) pizzaya +3 TL
Kullanici yanina bir de içecek alacaksa
Pizza boyutu fark etmeksizin +2 TL

"""

"""
Adim 1: Başla
Adim 2: Kullanicidan pizza boyutunu al (S, M, L)
Adim 3: Kullanicidan extra peynir tercihini al (E, H)
Adim 4: Kullanicidan içecek tercihini al (E, H)
Adim 5: Alinan pizza boyutuna göre temel ücreti belirle
Adim 6: Eğer kullanici extra peynir isterse, temel ücrete ekstra peynir ücretini ekle
Adim 7: Eğer kullanici içecek isterse, ücrete içecek ücretini ekle
Adim 8: Toplam ücreti hesapla
Adim 9: Toplam ücreti yazdir
Adim 10: Bitir

"""
while True:

    try:
        pizza = input("pizza boyutunu seçiniz (S,M,L) : ").lower()

        if pizza == "s" :
            fiat = 25

        elif pizza == "m" :
            fiat = 30

        elif pizza == "l" :
            fiat = 35

        print("toplam fiat : " , fiat , "tl")

    except NameError :
        print("lütfen s , m , l harflerinden birini tuşlayiniz")
        continue

    

    while True:
        extra_peynir = input("ekstra peynir almak ister misiniz (E/H) : ").lower()
        if extra_peynir == "e" or extra_peynir == "h" :
            if extra_peynir == "e":
                if pizza == "s":
                    fiat += 2
                
                elif pizza == "m" or pizza == "l" :
                    fiat += 3

            print("toplam fiat : " ,fiat , "tl")
            break
        
        else:
            print("lütfen e veya h harflerinden birini tuşlayiniz.")
            continue

    while True:

        içecek = input("içecek almak ister misiniz (E/H) : ").lower()

        if içecek == "e":
            fiat += 2
            print("toplam fiat : " ,fiat , "tl")
            break
            
        elif içecek == "h":
            fiat
            print("toplam fiat : " ,fiat , "tl")
            break
    break
